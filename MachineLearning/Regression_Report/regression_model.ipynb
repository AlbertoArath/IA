# %%
from ucimlrepo import fetch_ucirepo 
from tabulate import tabulate
import pandas as pd

# fetch dataset 
energy_efficiency = fetch_ucirepo (id=242) 
  
# data (as pandas dataframes) 
X = energy_efficiency.data.features 
y = energy_efficiency.data.targets 
  
# metadata 
#print(energy_efficiency.metadata) 
  
# variable information 
print(energy_efficiency.variables) 
x = 0

# Check if 'df' is a DataFrame
if isinstance(energy_efficiency.variables, pd.DataFrame):
#if isinstance(x, pd.DataFrame):
    print("The object 'df' is a DataFrame.")
else:
    print("The object 'df' is NOT a DataFrame.")
# Out:
#   name     role        type demographic                description units  \
# 0   X1  Feature  Continuous        None       Relative Compactness  None
# 1   X2  Feature  Continuous        None               Surface Area  None
# 2   X3  Feature  Continuous        None                  Wall Area  None
# 3   X4  Feature  Continuous        None                  Roof Area  None
# 4   X5  Feature  Continuous        None             Overall Height  None
# 5   X6  Feature     Integer        None                Orientation  None
# 6   X7  Feature  Continuous        None               Glazing Area  None
# 7   X8  Feature     Integer        None  Glazing Area Distribution  None
# 8   Y1   Target  Continuous        None               Heating Load  None
# 9   Y2   Target  Continuous        None               Cooling Load  None
#
#   missing_values
# 0             no
# 1             no
# 2             no
# 3             no
# 4             no
# 5             no
# 6             no
# 7             no
# 8             no
# 9             no
# The object 'df' is a DataFrame.

# %%
energy_efficiency.variables
# Out:
#   name     role        type demographic                description units  \
# 0   X1  Feature  Continuous        None       Relative Compactness  None
# 1   X2  Feature  Continuous        None               Surface Area  None
# 2   X3  Feature  Continuous        None                  Wall Area  None
# 3   X4  Feature  Continuous        None                  Roof Area  None
# 4   X5  Feature  Continuous        None             Overall Height  None
# 5   X6  Feature     Integer        None                Orientation  None
# 6   X7  Feature  Continuous        None               Glazing Area  None
# 7   X8  Feature     Integer        None  Glazing Area Distribution  None
# 8   Y1   Target  Continuous        None               Heating Load  None
# 9   Y2   Target  Continuous        None               Cooling Load  None
#
#   missing_values
# 0             no
# 1             no
# 2             no
# 3             no
# 4             no
# 5             no
# 6             no
# 7             no
# 8             no
# 9             no

# %%
energy_efficiency.data.features
# Out:
#        X1     X2     X3      X4   X5  X6   X7  X8
# 0    0.98  514.5  294.0  110.25  7.0   2  0.0   0
# 1    0.98  514.5  294.0  110.25  7.0   3  0.0   0
# 2    0.98  514.5  294.0  110.25  7.0   4  0.0   0
# 3    0.98  514.5  294.0  110.25  7.0   5  0.0   0
# 4    0.90  563.5  318.5  122.50  7.0   2  0.0   0
# ..    ...    ...    ...     ...  ...  ..  ...  ..
# 763  0.64  784.0  343.0  220.50  3.5   5  0.4   5
# 764  0.62  808.5  367.5  220.50  3.5   2  0.4   5
# 765  0.62  808.5  367.5  220.50  3.5   3  0.4   5
# 766  0.62  808.5  367.5  220.50  3.5   4  0.4   5
# 767  0.62  808.5  367.5  220.50  3.5   5  0.4   5
#
# [768 rows x 8 columns]

# %%
energy_efficiency.variables
# Out:
#   name     role        type demographic                description units  \
# 0   X1  Feature  Continuous        None       Relative Compactness  None
# 1   X2  Feature  Continuous        None               Surface Area  None
# 2   X3  Feature  Continuous        None                  Wall Area  None
# 3   X4  Feature  Continuous        None                  Roof Area  None
# 4   X5  Feature  Continuous        None             Overall Height  None
# 5   X6  Feature     Integer        None                Orientation  None
# 6   X7  Feature  Continuous        None               Glazing Area  None
# 7   X8  Feature     Integer        None  Glazing Area Distribution  None
# 8   Y1   Target  Continuous        None               Heating Load  None
# 9   Y2   Target  Continuous        None               Cooling Load  None
#
#   missing_values
# 0             no
# 1             no
# 2             no
# 3             no
# 4             no
# 5             no
# 6             no
# 7             no
# 8             no
# 9             no

# %%
explanatory_var = ["Relative Compactness", "Surface Area", "Wall Area", "Roof Area", "Overall Height", "Orientation", "Glazing Area", "Glazing Area Distribution"]
energy_efficiency.data.features.columns  = ["Relative Compactness", "Surface Area", "Wall Area", "Roof Area", "Overall Height", "Orientation", "Glazing Area", "Glazing Area Distribution"]
energy_efficiency.data.features
#X = energy_efficiency[features_names]
#y = energy_efficiency[target_variable]
# Out:
#      Relative Compactness  Surface Area  Wall Area  Roof Area  Overall Height  \
# 0                    0.98         514.5      294.0     110.25             7.0
# 1                    0.98         514.5      294.0     110.25             7.0
# 2                    0.98         514.5      294.0     110.25             7.0
# 3                    0.98         514.5      294.0     110.25             7.0
# 4                    0.90         563.5      318.5     122.50             7.0
# ..                    ...           ...        ...        ...             ...
# 763                  0.64         784.0      343.0     220.50             3.5
# 764                  0.62         808.5      367.5     220.50             3.5
# 765                  0.62         808.5      367.5     220.50             3.5
# 766                  0.62         808.5      367.5     220.50             3.5
# 767                  0.62         808.5      367.5     220.50             3.5
#
#      Orientation  Glazing Area  Glazing Area Distribution
# 0              2           0.0                          0
# 1              3           0.0                          0
# 2              4           0.0                          0
# 3              5           0.0                          0
# 4              2           0.0                          0
# ..           ...           ...                        ...
# 763            5           0.4                          5
# 764            2           0.4                          5
# 765            3           0.4                          5
# 766            4           0.4                          5
# 767            5           0.4                          5
#
# [768 rows x 8 columns]

# %%
energy_efficiency.variables
# Out:
#   name     role        type demographic                description units  \
# 0   X1  Feature  Continuous        None       Relative Compactness  None
# 1   X2  Feature  Continuous        None               Surface Area  None
# 2   X3  Feature  Continuous        None                  Wall Area  None
# 3   X4  Feature  Continuous        None                  Roof Area  None
# 4   X5  Feature  Continuous        None             Overall Height  None
# 5   X6  Feature     Integer        None                Orientation  None
# 6   X7  Feature  Continuous        None               Glazing Area  None
# 7   X8  Feature     Integer        None  Glazing Area Distribution  None
# 8   Y1   Target  Continuous        None               Heating Load  None
# 9   Y2   Target  Continuous        None               Cooling Load  None
#
#   missing_values
# 0             no
# 1             no
# 2             no
# 3             no
# 4             no
# 5             no
# 6             no
# 7             no
# 8             no
# 9             no

# %%
from sklearn.model_selection import train_test_split
import random

random_seed = 32
random.seed(random_seed)
X_train, X_test, y_train, y_test = train_test_split (X, y, test_size=0.2, random_state=random_seed)

# %%
print(X.shape)
print(y.shape)
print(y_test.shape)
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (768, 8)
# (768, 2)
# (154, 2)
# (614, 8)
# (614, 2)
# (154, 8)
# (154, 2)

# %%
categorical_variables = ["Orientation"]

numerical_variables = [var for var in explanatory_var if var not in categorical_variables]

print (numerical_variables)

print (categorical_variables)
# Out:
# ['Relative Compactness', 'Surface Area', 'Wall Area', 'Roof Area', 'Overall Height', 'Glazing Area', 'Glazing Area Distribution']
# ['Orientation']

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

numerical_pipeline = Pipeline([
    ("imputer", SimpleImputer(strategy="mean"))
    ("scaler", StandardScaler())
])

preprocessing_pipeline = ColumnTransformer([
    ("num_pipeline", numerical_pipeline, numerical_variables),
    ("encoder", OneHotEncoder(), categorical_variables)
])

#X_train_transformed = preprocessing_pipeline.fit_transform(X_train)
#X_train_transformed


#print(X_train_transformed.shape)

# %%
#pd.DataFrame (X_train_transformed)

# %%
pd.DataFrame (X_train)
# Out:
#      Relative Compactness  Surface Area  Wall Area  Roof Area  Overall Height  \
# 196                  0.90         563.5      318.5     122.50             7.0
# 22                   0.76         661.5      416.5     122.50             7.0
# 137                  0.64         784.0      343.0     220.50             3.5
# 469                  0.66         759.5      318.5     220.50             3.5
# 627                  0.98         514.5      294.0     110.25             7.0
# ..                    ...           ...        ...        ...             ...
# 403                  0.79         637.0      343.0     147.00             7.0
# 88                   0.64         784.0      343.0     220.50             3.5
# 310                  0.76         661.5      416.5     122.50             7.0
# 555                  0.74         686.0      245.0     220.50             3.5
# 727                  0.90         563.5      318.5     122.50             7.0
#
#      Orientation  Glazing Area  Glazing Area Distribution
# 196            2          0.10                          4
# 22             4          0.00                          0
# 137            3          0.10                          2
# 469            3          0.25                          4
# 627            5          0.40                          3
# ..           ...           ...                        ...
# 403            5          0.25                          3
# 88             2          0.10                          1
# 310            4          0.25                          1
# 555            5          0.40                          1
# 727            5          0.40                          5
#
# [614 rows x 8 columns]

# %%
from sklearn.linear_model import LinearRegression

regressor_pipeline = Pipeline([
    ("preprocessing", preprocessing_pipeline),
    ("regressor", LinearRegression())
])

# %%
regressor_pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(transformers=[('num_pipeline',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer())]),
#                                                   ['Relative Compactness',
#                                                    'Surface Area', 'Wall Area',
#                                                    'Roof Area',
#                                                    'Overall Height',
#                                                    'Glazing Area',
#                                                    'Glazing Area '
#                                                    'Distribution']),
#                                                  ('encoder', OneHotEncoder(),
#                                                   ['Orientation'])])),
#                 ('regressor', LinearRegression())])

# %%
regressor_pipeline.score(X_train, y_train)
# Out:
# 0.9002831168263717

# %%
regressor_pipeline.score(X_test, y_test)
# Out:
# 0.9059275270660962

# %%
predictions_train = regressor_pipeline.predict(X_train)
predictions_train
# Out:
# array([[27.99539495, 30.2454927 ],
#        [31.37039495, 33.7767427 ],
#        [12.12039495, 14.8079927 ],
#        ...,
#        [36.46414495, 37.4954927 ],
#        [13.69825724, 16.93533099],
#        [33.92481974, 35.06033099]])

# %%
predictions_test = regressor_pipeline.predict(X_train)
predictions_test = regressor_pipeline.predict(X_test)

predictions_test
# Out:
# array([[35.58914495, 36.4017427 ],
#        [40.12794474, 40.52908099],
#        [37.32351995, 37.5579927 ],
#        [17.05789495, 18.6829927 ],
#        [25.04981974, 28.12283099],
#        [32.63601995, 33.8392427 ],
#        [35.57351995, 36.4329927 ],
#        [ 9.71414495, 13.1517427 ],
#        [13.10476995, 15.7142427 ],
#        [ 9.55789495, 13.3861177 ],
#        [18.90164495, 20.0579927 ],
#        [24.91726995, 27.2142427 ],
#        [33.04226995, 33.5267427 ],
#        [28.22976995, 30.9954927 ],
#        [10.66726995, 14.0267427 ],
#        [24.81544474, 28.02908099],
#        [30.19851995, 31.6204927 ],
#        [29.69851995, 31.5892427 ],
#        [16.00320745, 17.6517427 ],
#        [25.66726995, 27.9329927 ],
#        [33.62039495, 34.4017427 ],
#        [12.89383245, 15.8079927 ],
#        [27.20606974, 30.84158099],
#        [16.05789495, 18.0579927 ],
#        [11.78419474, 15.52908099],
#        [16.33106974, 18.49783099],
#        [30.16726995, 31.9329927 ],
#        [35.33914495, 36.3392427 ],
#        [14.41726995, 17.0579927 ],
#        [31.22976995, 32.1829927 ],
#        [14.63601995, 17.1517427 ],
#        [ 8.95606974, 13.62283099],
#        [13.83914495, 16.5579927 ],
#        [12.82351995, 15.1829927 ],
#        [18.01101995, 19.5579927 ],
#        [27.30789495, 30.0267427 ],
#        [15.61258245, 17.8236177 ],
#        [17.94851995, 19.1204927 ],
#        [15.54226995, 17.4173677 ],
#        [39.54226995, 39.3704927 ],
#        [15.15164495, 17.5892427 ],
#        [ 9.97976995, 13.6517427 ],
#        [ 8.79981974, 13.09158099],
#        [26.74539495, 28.9954927 ],
#        [18.93289495, 20.0267427 ],
#        [31.60476995, 33.3704927 ],
#        [35.13601995, 36.1829927 ],
#        [26.02664495, 28.9954927 ],
#        [ 9.74539495, 13.5892427 ],
#        [15.44825724, 18.21658099],
#        [30.80789495, 31.9017427 ],
#        [15.84695745, 17.9329927 ],
#        [18.76856974, 20.43533099],
#        [25.15164495, 27.3079927 ],
#        [29.79981974, 32.09158099],
#        [30.09669474, 32.43533099],
#        [15.07351995, 16.9642427 ],
#        [29.66726995, 31.1517427 ],
#        [36.98731974, 38.24783099],
#        [33.13601995, 34.2142427 ],
#        [34.61231974, 36.02908099],
#        [33.58914495, 34.4329927 ],
#        [13.17481974, 16.24783099],
#        [34.05789495, 34.6517427 ],
#        [34.66726995, 35.9329927 ],
#        [24.74539495, 27.4954927 ],
#        [15.86231974, 18.27908099],
#        [40.46414495, 39.8079927 ],
#        [14.98731974, 17.98220599],
#        [17.74539495, 19.0267427 ],
#        [11.36231974, 15.27908099],
#        [19.33914495, 19.8392427 ],
#        [24.01856974, 28.02908099],
#        [28.33106974, 31.46658099],
#        [28.88601995, 30.9017427 ],
#        [37.08914495, 37.4329927 ],
#        [31.15164495, 33.1517427 ],
#        [31.94851995, 33.3704927 ],
#        [35.65919474, 36.93533099],
#        [32.01856974, 33.90408099],
#        [40.05789495, 39.9954927 ],
#        [30.19851995, 32.3704927 ],
#        [12.62039495, 15.5267427 ],
#        [15.80789495, 17.9642427 ],
#        [31.56544474, 32.77908099],
#        [11.74539495, 14.9954927 ],
#        [11.22976995, 14.3704927 ],
#        [40.29226995, 40.0892427 ],
#        [ 7.80789495, 12.1204927 ],
#        [13.93263224, 17.06033099],
#        [ 8.56544474, 12.98220599],
#        [10.41726995, 13.5267427 ],
#        [33.00294474, 34.59158099],
#        [27.30789495, 29.9017427 ],
#        [10.88601995, 13.9798677 ],
#        [11.71388224, 15.24783099],
#        [ 9.61231974, 13.96658099],
#        [35.99539495, 36.2454927 ],
#        [34.29981974, 36.21658099],
#        [12.76856974, 16.21658099],
#        [11.05789495, 14.6517427 ],
#        [32.12039495, 33.0892427 ],
#        [25.40164495, 27.8704927 ],
#        [12.53419474, 16.06033099],
#        [14.92508245, 17.4642427 ],
#        [ 8.43289495, 12.0579927 ],
#        [17.61231974, 19.84158099],
#        [31.02664495, 32.0267427 ],
#        [ 7.81570745, 12.1048677 ],
#        [13.45606974, 16.56033099],
#        [30.74539495, 31.5267427 ],
#        [16.04226995, 18.0892427 ],
#        [27.33914495, 30.4642427 ],
#        [14.15164495, 16.5267427 ],
#        [31.01101995, 32.0579927 ],
#        [11.15164495, 14.5267427 ],
#        [28.19851995, 29.9017427 ],
#        [33.08914495, 34.0892427 ],
#        [ 9.94851995, 13.2454927 ],
#        [18.16726995, 19.2454927 ],
#        [15.99539495, 17.9017427 ],
#        [37.45606974, 38.46658099],
#        [25.18289495, 27.7454927 ],
#        [25.50294474, 28.37283099],
#        [24.15164495, 27.6517427 ],
#        [31.38601995, 33.2454927 ],
#        [17.12039495, 19.0579927 ],
#        [26.32351995, 29.2142427 ],
#        [27.62794474, 30.49783099],
#        [33.74539495, 35.4954927 ],
#        [25.60476995, 27.5579927 ],
#        [34.54226995, 35.4954927 ],
#        [12.20633245, 15.4486177 ],
#        [28.42481974, 30.52908099],
#        [12.70606974, 15.96658099],
#        [33.15164495, 34.4642427 ],
#        [15.76883245, 17.5423677 ],
#        [ 9.15919474, 13.66970599],
#        [19.10476995, 19.7454927 ],
#        [37.12039495, 37.8704927 ],
#        [26.05789495, 29.4329927 ],
#        [37.35476995, 37.9954927 ],
#        [15.90919474, 18.46658099],
#        [32.94044474, 34.34158099],
#        [12.87039495, 15.4017427 ],
#        [39.89356974, 40.40408099],
#        [27.83914495, 29.3704927 ],
#        [10.31544474, 14.34158099],
#        [32.80789495, 33.4329927 ],
#        [15.40919474, 18.06033099],
#        [32.29981974, 34.56033099],
#        [15.64356974, 18.15408099],
#        [17.33914495, 19.1829927 ],
#        [16.02664495, 17.8704927 ]])

# %%
from sklearn.metrics import mean_squared_error as mse
import numpy as np 

print (np.sqrt(mse(y_train, predictions_train)))
print (np.sqrt(mse(y_test, predictions_test)))
# Out:
# 3.046102442405912
# 3.118605335871328

# %%
#3.041742935312052
#3.1158761198333655
y_train
# Out:
#         Y1     Y2
# 196  29.06  29.34
# 22   24.77  29.79
# 137  15.18  19.34
# 469  13.00  15.59
# 627  32.75  34.00
# ..     ...    ...
# 403  39.83  36.87
# 88   15.41  19.37
# 310  36.91  37.45
# 555  14.55  17.25
# 727  35.24  37.27
#
# [614 rows x 2 columns]

# %%
regressor_pipeline.named_steps["regressor"].coef_
# Out:
# array([[-6.21261611e+01,  2.55155354e+11, -2.55155354e+11,
#         -5.10310708e+11,  4.20883345e+00,  1.94101579e+01,
#          2.31194421e-01, -2.67922904e+08, -2.67922905e+08,
#         -2.67922905e+08, -2.67922905e+08],
#        [-6.70936944e+01,  4.85739941e+11, -4.85739941e+11,
#         -9.71479882e+11,  4.01373129e+00,  1.43721458e+01,
#          1.15426780e-01, -5.10045562e+08, -5.10045563e+08,
#         -5.10045562e+08, -5.10045562e+08]])
