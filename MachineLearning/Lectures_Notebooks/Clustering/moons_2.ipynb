# %% [markdown]
# ## Moons

# %%
from sklearn.datasets import make_moons

# %%
X, y = make_moons(n_samples=(200,200), noise=0.05, random_state=33)

print(X.shape)
print(y.shape)
# Out:
# (400, 2)
# (400,)

# %%
import matplotlib.pyplot as plt

plt.scatter(X[:, 0], X[:, 1], c='blue')

# %%
from sklearn.cluster import KMeans
from sklearn.cluster import DBSCAN


k = 2
kmeans_model = DBSCAN(eps=.08,
                      min_samples=5).fit(X)

# %%
labels = kmeans_model.labels_
labels[:200]
# Out:
# array([ 0,  1,  1,  2,  5,  2,  1,  8,  2, -1,  1,  1, -1,  1,  1,  3,  4,
#         1,  0,  2,  1,  5, -1,  1,  6,  5,  7,  7,  2,  1,  1,  1,  1, -1,
#         1,  2,  1,  5,  0,  8,  2,  1,  3,  1,  1,  7,  1,  1,  2,  5,  4,
#         7,  4,  2,  1,  9,  7,  5,  1,  5,  7,  1,  1,  1,  1, -1,  1,  2,
#         1,  1,  8,  7,  1,  4,  1,  1,  9,  1,  1,  1,  1, -1,  1,  5,  1,
#         1,  1,  1,  6,  5,  5,  3, -1,  1,  1,  6,  2,  3,  1,  0,  4,  2,
#         9,  2,  7,  2,  6,  1,  7,  8,  1,  9,  2,  5,  1,  7,  1,  1,  1,
#         5,  8,  3,  1,  2,  1,  5, -1,  5,  7,  1,  1,  2,  5,  1,  3,  1,
#         1,  7,  2,  5,  5,  5,  0,  5,  7,  7,  6,  9,  2,  2,  2,  7,  6,
#         3,  1,  7,  2,  1,  2,  7,  5, -1,  5,  1,  2,  5,  9,  2,  7,  0,
#         1, -1,  2,  1,  1, -1,  5,  6,  3,  1,  5,  6,  3,  1,  1,  5,  2,
#         1,  0,  1,  1,  2,  2, -1,  3,  1,  7,  1,  1,  1], dtype=int64)

# %%
#centroids = kmeans_model.cluster_centers_
#centroids

# %%
#plt.scatter(X[labels == 0, 0], X[labels == 0, 1], c = 'red')
#plt.scatter(X[labels == 1, 0], X[labels == 1, 1], c = 'blue')

plt.scatter(X[:, 0], X[:, 1], c = labels)

#plt.scatter(centroids[0, 0], centroids[0, 1], c = 'red', marker = "X", s = 400)
#plt.scatter(centroids[1, 0], centroids[1, 1], c = 'blue', marker = "X", s = 400)
