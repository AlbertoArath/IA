# %% [markdown]
# ![Self](https://media.licdn.com/dms/image/v2/C5603AQEFqpifp49O7A/profile-displayphoto-shrink_800_800/profile-displayphoto-shrink_800_800/0/1604296430800?e=1730332800&v=beta&t=SV5VIWtjWuR97SlQ91M7IafpMQI0UJN022ISXRA216A)

# %% [markdown]
# **Name:** Alberto Arath Figueroa Salomon
# **Age:** 29
# **Profession:** Firmware Silicon Engineer at Intel
#
# ## Hobbies
#
# I like to make specialty coffee, swim and do math in my spare time.
