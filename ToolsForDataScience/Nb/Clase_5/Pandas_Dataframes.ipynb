# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %%
estados= ["Jalisco"]*4 +["Colima"]*4
estados
# Out:
# ['Jalisco',
#  'Jalisco',
#  'Jalisco',
#  'Jalisco',
#  'Colima',
#  'Colima',
#  'Colima',
#  'Colima']

# %%
años= [2000,2005,2010,2020]*2
años
# Out:
# [2000, 2005, 2010, 2020, 2000, 2005, 2010, 2020]

# %%
poblaciones= [6.32, 6.75, 7.35, 8.34] + [0.54, .57, .65, .73 ]
estados, años, poblaciones
# Out:
# (['Jalisco',
#   'Jalisco',
#   'Jalisco',
#   'Jalisco',
#   'Colima',
#   'Colima',
#   'Colima',
#   'Colima'],
#  [2000, 2005, 2010, 2020, 2000, 2005, 2010, 2020],
#  [6.32, 6.75, 7.35, 8.34, 0.54, 0.57, 0.65, 0.73])

# %%
datos= {"Estado": estados, "Año": años, "Población": poblaciones}
datos
# Out:
# {'Estado': ['Jalisco',
#   'Jalisco',
#   'Jalisco',
#   'Jalisco',
#   'Colima',
#   'Colima',
#   'Colima',
#   'Colima'],
#  'Año': [2000, 2005, 2010, 2020, 2000, 2005, 2010, 2020],
#  'Población': [6.32, 6.75, 7.35, 8.34, 0.54, 0.57, 0.65, 0.73]}

# %%
df1=DataFrame(datos)
df1
# Out:
#     Estado   Año  Población
# 0  Jalisco  2000       6.32
# 1  Jalisco  2005       6.75
# 2  Jalisco  2010       7.35
# 3  Jalisco  2020       8.34
# 4   Colima  2000       0.54
# 5   Colima  2005       0.57
# 6   Colima  2010       0.65
# 7   Colima  2020       0.73

# %%
display (df1.values)
display (df1.index)
display (df1.columns)

df1 = DataFrame (datos, index=datos["Estado"])
df1.loc["Jalisco"]
index = list ("abcdefgh")
df1.index = index
df1.index
# Out:
# array([['Jalisco', 2000, 6.32],
#        ['Jalisco', 2005, 6.75],
#        ['Jalisco', 2010, 7.35],
#        ['Jalisco', 2020, 8.34],
#        ['Colima', 2000, 0.54],
#        ['Colima', 2005, 0.57],
#        ['Colima', 2010, 0.65],
#        ['Colima', 2020, 0.73]], dtype=object)
# RangeIndex(start=0, stop=8, step=1)
# Index(['Estado', 'Año', 'Población'], dtype='object')
# Index(['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h'], dtype='object')

# %% [markdown]
# Manejjo de datos en el data frame

# %%
df1.head(3) #tail..
# Out:
#     Estado   Año  Población
# a  Jalisco  2000       6.32
# b  Jalisco  2005       6.75
# c  Jalisco  2010       7.35

# %%
df1["Población"]
# Out:
# a    6.32
# b    6.75
# c    7.35
# d    8.34
# e    0.54
# f    0.57
# g    0.65
# h    0.73
# Name: Población, dtype: float64

# %%
df1.loc["a", :]
# Out:
# Estado       Jalisco
# Año             2000
# Población       6.32
# Name: a, dtype: object

# %%
df1.loc["a":"d", ["Estado", "Población"]]
# Out:
#     Estado  Población
# a  Jalisco       6.32
# b  Jalisco       6.75
# c  Jalisco       7.35
# d  Jalisco       8.34

# %%
df1["deuda"] = None

# %%
df1["deuda2"] = np.arange(0, 8, 1)
df1
# Out:
#     Estado   Año  Población deuda  deuda2
# a  Jalisco  2000       6.32  None       0
# b  Jalisco  2005       6.75  None       1
# c  Jalisco  2010       7.35  None       2
# d  Jalisco  2020       8.34  None       3
# e   Colima  2000       0.54  None       4
# f   Colima  2005       0.57  None       5
# g   Colima  2010       0.65  None       6
# h   Colima  2020       0.73  None       7

# %%
del df1["deuda2"]

# %%
df1["Poblacion Futura"] = df1.loc[:, "Población"] * 1.1

df2 = DataFrame (df1, columns=["Año", "Estado", "Poblacion Futura"])

# %%
for df in df2.groupby (by="Año"):
  display(df)
# Out:
# (2000,
#      Año   Estado  Poblacion Futura
#  a  2000  Jalisco             6.952
#  e  2000   Colima             0.594)
# (2005,
#      Año   Estado  Poblacion Futura
#  b  2005  Jalisco             7.425
#  f  2005   Colima             0.627)
# (2010,
#      Año   Estado  Poblacion Futura
#  c  2010  Jalisco             8.085
#  g  2010   Colima             0.715)
# (2020,
#      Año   Estado  Poblacion Futura
#  d  2020  Jalisco             9.174
#  h  2020   Colima             0.803)

# %%
df2.groupby(by="Estado").sum()["Poblacion Futura"]
# Out:
# Estado
# Colima      2.739
# Jalisco    31.636
# Name: Poblacion Futura, dtype: float64
