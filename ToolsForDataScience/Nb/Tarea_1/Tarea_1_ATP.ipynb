# %%
# !wget https://github.com/DRMiguelAR/Herramientas_Analisis/raw/master/tennis_data.csv
## Obtenido de http://www.tennis-data.co.uk/data.php
# Out:
# --2024-08-24 17:06:20--  https://github.com/DRMiguelAR/Herramientas_Analisis/raw/master/tennis_data.csv
# Resolving github.com (github.com)... 140.82.113.4
# Connecting to github.com (github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/DRMiguelAR/Herramientas_Analisis/master/tennis_data.csv [following]
# --2024-08-24 17:06:20--  https://raw.githubusercontent.com/DRMiguelAR/Herramientas_Analisis/master/tennis_data.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7065778 (6.7M) [text/plain]
# Saving to: ‘tennis_data.csv’
#
# tennis_data.csv     100%[===================>]   6.74M  --.-KB/s    in 0.1s
#
# ...

# %% [markdown]
# Temas:
# Formatos en Markdown
# Lectura y escritura de archivos
# Guardado de datos tabulares: NamedTuple, Clases, Diccionarios
# Funciones de ordenamiento
# Counter
# Datetime
#
# Nombre más Largo
# Apellido con más vocales
#
#
# # Integrantes del equipo:
#
# Contesta las siguientes preguntas, __sin__ utilizar la librería Pandas.
#
# - Nombre 1
# - Nombre 2

# %% [markdown]
# # Manejo de datos
# - En la primer línea del archivo se encuentrar las categorías, extrae esa información.
#
# > _Comandos: open, readline_
# > _Librerías: csv_

# %%
# prompt: wget a this csv file a create a csv object https://github.com/DRMiguelAR/Herramientas_Analisis/raw/master/tennis_data.csv and print first 2 rows

# !wget https://github.com/DRMiguelAR/Herramientas_Analisis/raw/master/tennis_data.csv
import csv
list_dic = list ()
file =  open('tennis_data.csv', 'r')
csv_reader = csv.reader(file)
# Out:
# --2024-08-24 17:39:57--  https://github.com/DRMiguelAR/Herramientas_Analisis/raw/master/tennis_data.csv
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/DRMiguelAR/Herramientas_Analisis/master/tennis_data.csv [following]
# --2024-08-24 17:39:57--  https://raw.githubusercontent.com/DRMiguelAR/Herramientas_Analisis/master/tennis_data.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7065778 (6.7M) [text/plain]
# Saving to: ‘tennis_data.csv.14’
#
# tennis_data.csv.14  100%[===================>]   6.74M  --.-KB/s    in 0.1s
#
# ...

# %%
# Out:
# ['ATP', 'Location', 'Tournament', 'Date', 'Series', 'Court', 'Surface', 'Round', 'Best of', 'Winner', 'Loser', 'WRank', 'LRank', 'WPts', 'LPts', 'W1', 'L1', 'W2', 'L2', 'W3', 'L3', 'W4', 'L4', 'W5', 'L5', 'Comment', 'pl1_flag', 'pl1_year_pro', 'pl1_weight', 'pl1_height', 'pl1_hand', 'pl2_flag', 'pl2_year_pro', 'pl2_weight', 'pl2_height', 'pl2_hand']

# %% [markdown]
# - Crea una lista con cada partido, donde los datos de cada partido sean un diccionario o un objeto. Con las categorías como llave y el valor como el contenido.

# %%
header = next(csv_reader)
print (header)
for row in csv_reader:
    list_dic.append(dict(zip(header, row)))
# Out:
# ['ATP', 'Location', 'Tournament', 'Date', 'Series', 'Court', 'Surface', 'Round', 'Best of', 'Winner', 'Loser', 'WRank', 'LRank', 'WPts', 'LPts', 'W1', 'L1', 'W2', 'L2', 'W3', 'L3', 'W4', 'L4', 'W5', 'L5', 'Comment', 'pl1_flag', 'pl1_year_pro', 'pl1_weight', 'pl1_height', 'pl1_hand', 'pl2_flag', 'pl2_year_pro', 'pl2_weight', 'pl2_height', 'pl2_hand']

# %% [markdown]
# # Filtrado de datos 2021
#  ### Con el conjunto de partidos del 2021:
#
# - Haz un conjunto de todos los nombres de ganadores de partidos.

# %%
winners = list()
for g in list_dic:
  winners.append(g['Winner'])

print(winners)
# Out:
# ['Kwon S.W.', 'Monteiro T.', 'Djere L.', 'Johnson S.', 'Moutet C.', 'Daniel T.', 'Gerasimov E.', 'Ymer M.', 'Cerundolo J.M.', 'Paul T.', 'Mager G.', 'Kokkinakis T.', 'Djere L.', 'Cilic M.', 'Ymer M.', 'Kokkinakis T.', 'Paul T.', 'Gerasimov E.', 'Khachanov K.', 'Monfils G.', 'Cilic M.', 'Monfils G.', 'Khachanov K.', 'Kokkinakis T.', 'Khachanov K.', 'Monfils G.', 'Monfils G.', 'Bagnis F.', 'Van De Zandschulp B.', 'Mcdonald M.', 'Griekspoor T.', 'Berankis R.', 'Thompson J.', 'Ruusuvuori E.', 'Laaksonen H.', 'Molcan A.', 'Popyrin A.', 'Cressy M.', 'Munar J.', 'Ruusuvuori E.', 'Molcan A.', 'Dimitrov G.', 'Nadal R.', 'Munar J.', 'Griekspoor T.', 'Cressy M.', 'Van De Zandschulp B.', 'Ruusuvuori E.', 'Nadal R.', 'Cressy M.', 'Dimitrov G.', 'Cressy M.', 'Nadal R.', 'Nadal R.', 'Vukic A.', 'Paul T.', 'Rinderknech A.', 'Munar J.', 'Moutet C.', 'Kwon S.W.', 'Johnson S.', 'Bonzi B.', 'Fucsovics M.', 'Mager G.', 'Kokkinakis T.', 'Monteiro T.', 'Rinderknech A.', 'Cilic M.', 'Paul T.', 'Khachanov K.
# ...

# %% [markdown]
# - Haz un conjunto de todos los nombres de perdedores de partidos.

# %%
# perdedores
losers = list()
for g in list_dic:
  losers.append(g['Loser'])

print(losers)
# Out:
# ['Nishioka Y.', 'Altmaier D.', 'Carballes Baena R.', 'Vukic A.', 'Rune H.', 'Musetti L.', 'Fucsovics M.', 'Bonzi B.', 'Bolt A.', 'Vesely J.', 'Cerundolo F.', 'Millman J.', 'Moutet C.', 'Monteiro T.', 'Kwon S.W.', 'Tiafoe F.', 'Daniel T.', 'Mager G.', 'Johnson S.', 'Cerundolo J.M.', 'Djere L.', 'Paul T.', 'Gerasimov E.', 'Ymer M.', 'Cilic M.', 'Kokkinakis T.', 'Khachanov K.', 'Murray A.', 'Mannarino A.', 'Gojowczyk P.', 'Koepfer D.', 'Giron M.', 'O Connell C.', 'Baez S.', 'Paire B.', 'Seppi A.', 'Travaglia S.', 'Hijikata R.', 'Anderson K.', 'Thompson J.', 'Goffin D.', 'Bagnis F.', 'Berankis R.', 'Laaksonen H.', 'Popyrin A.', 'Opelka R.', 'Mcdonald M.', 'Molcan A.', 'Griekspoor T.', 'Munar J.', 'Van De Zandschulp B.', 'Dimitrov G.', 'Ruusuvuori E.', 'Cressy M.', 'Bublik A.', 'Tiafoe F.', 'Mcdonald M.', 'Millman J.', 'Struff J.L.', 'Harris L.', 'Bolt A.', 'Carballes Baena R.', 'Van De Zandschulp B.', 'Gerasimov E.', 'Paire B.', 'Nishioka Y.', 'Kwon S.W.', 'Munar J.', 'Bonzi B.', 'Mager 
# ...

# %% [markdown]
# - Enlista qué jugadores no han perdido ningún partido.

# %%
# no han ganado
invicted = set(winners) - set(losers)
print(set(winners))
print(set(losers))
print(invicted)
# Out:
# {'Jarry N.', '', 'Gaio F.', 'Statham J.', 'Lehecka J.', 'Medvedev D.', 'Andreev A.', 'Ito T.', 'Lapentti N.', 'Tabilo A.', 'Petrovic D.', 'Bellucci T.', 'Reynolds B.', 'Hernandez O.', 'Lopez-Jaen M.A.', 'Diez S.', 'Serdarusic N.', 'Bai Y.', 'Paul T.', 'Dodig I.', 'Ferrer D.', 'Stebe C.M.', 'Munoz-De La Nava D.', 'Ward J.', 'Eubanks C.', 'Sergeyev I.', 'Harrison C.', 'Olivetti A.', 'Zopp J.', 'Schuettler R.', 'King K.', 'Johansson J.', 'Kicker N.', 'Cachin P.', 'Przysiezny M.', 'Peliwo F.', 'Dasnieres de Veigy J.', 'Koepfer D.', 'Reister J.', 'Del Potro J.M.', 'Rubin N.', 'Mayer F.', 'Ilhan M.', 'Pavic M.', 'Kim K.', 'Erler A.', 'Majchrzak K.', 'Giustino L.', 'Dabul B.', 'Michon A.', 'Montanes A.', 'Sweeting R.', 'Hrbaty D.', 'Hajek J.', 'Kuhn N.', 'Basic M.', 'Soderlund C.', 'Jaziri M.', 'Dimitrov G.', 'Sluiter R.', 'Trinker B.', 'Gonzalez A.', 'Shapovalov D.', 'Delic M.', 'Cruciat A.', 'Bloomfield R.', 'Ramos-Vinolas A.', 'Muller A.', 'Sandgren T.', 'Moya C.', 'Varillas J.P.', 'Hues
# ...

# %% [markdown]
# - ¿Cuántos jugadores no han ganado ningún partido?

# %%
# número de jugadores que no han perdido
NotWinners = set(losers) - set(winners)
print(len(NotWinners))
# Out:
# 348

# %% [markdown]
# - Enlista qué jugadores no han ganado ningún partido.

# %%
# no han ganado
print((NotWinners))
# Out:
# {'Grigelis L.', 'Molteni A.', 'Zhang Ze.', 'Zabaleta M.', 'Kirkin E.', 'Lazarov A.', 'Barrientos N.', 'Kumantsov A.', 'Galdon P.', 'Ebelthite C.', 'Ramirez C.', 'Ortega-Olmedo R.', 'Fraile G.', 'Takeuchi K.', 'Niki T.', 'Chvojka E.', 'Hernandez-Fernandez J.', 'Borvanov R.', 'Alawadhi O.', 'Desein N.', 'Idmbarek Y.', 'Hocevar R.', 'Lajola D.', 'Schoolkate T.', 'Nava E.', 'Granollers Pujol G.', 'Munoz de la Nava D.', 'Zayid M. S.', 'Luncanu P.A.', 'Vicente F.', 'Hank T.', 'Munoz de La Nava D.', 'Berta D.', 'Kindlmann D.', 'Gray A.', 'Tirante T.A.', 'Awadhy O.', 'Mukund S.', 'De Paula F.', 'Shane R.', 'Mertinak M.', 'Burquier G.', 'Neumayer L.', 'Walter L.', 'Lazov A.', 'Nedelko I.', 'Hutchins R.', 'Bangoura S.', 'Torebko P.', 'Ali Mutawa J.M.', 'Bogaerts R.', 'Gromley C.', 'Coppejans K.', 'Hernandez-Fernandez J', 'Betov S.', 'Tearney F.', 'Bester P.', 'Mayot H.', 'Trevisan M.', 'Riedi L.', 'Garza D.', 'Tiurnev E.', 'Chakravarthi C.', 'Ram A.', 'Granollers G.', 'Catarina L.', 'Van D. Me
# ...

# %% [markdown]
# - ¿Cuántos jugadores no han ganado ningún partido?

# %%
# número de jugadores que no han ganado

# %% [markdown]
# - Haz una lista diciendo cuántos partidos ha ganado cada jugador.

# %%
players = losers + winners
games_won = {p: 0 for p in set(players)}
for g in list_dic:
  games_won[g['Winner']]+=1

#for player, count in games_won.items():
#  print (player, count)

# %% [markdown]
# - Haz una lista diciendo cuántos partidos ha perdido cada jugador

# %%
# cantidad de partidos perdidos por jugador
players = losers + winners
games_lost = {p: 0 for p in set(players)}
for g in list_dic:
  games_lost[g['Loser']]+=1

#for player, count in games_lost.items():
#  print (player, count)

# %% [markdown]
# - Obtén el jugador con más partidos ganados.

# %%
# jugador con más partidos ganados
m = max(games_won, key=games_won.get)
print (m)
total = games_won[m]
# Out:
# Djokovic N.

# %% [markdown]
# - Obtén el jugador con más partidos perdidos

# %%
# jugador con más partidos perdidos
# jugador con más partidos ganados
m = min(games_lost, key=games_lost.get)
print (m)
total = games_lost[m]
# Out:
# Grigelis L.

# %% [markdown]
# - Obtén todos los jugadores que hayan llegado a semifinales

# %%
# Semifinalistas
# cantidad de partidos perdidos por jugador
semifinalist = list()
for g in list_dic:
  if (g['Round'] == 'Semifinals'):
    semifinalist.append(g['Winner'])
    semifinalist.append(g['Loser'])

print (set(semifinalist))
# Out:
# {'Jarry N.', 'Lehecka J.', 'Medvedev D.', 'Lapentti N.', 'Tabilo A.', 'Petrovic D.', 'Bellucci T.', 'Hernandez O.', 'Paul T.', 'Dodig I.', 'Ferrer D.', 'Stebe C.M.', 'Ward J.', 'Harrison C.', 'Zopp J.', 'Schuettler R.', 'Przysiezny M.', 'Koepfer D.', 'Del Potro J.M.', 'Mayer F.', 'Majchrzak K.', 'Dabul B.', 'Sweeting R.', 'Montanes A.', 'Hajek J.', 'Basic M.', 'Jaziri M.', 'Dimitrov G.', 'Sluiter R.', 'Shapovalov D.', 'Bloomfield R.', 'Ramos-Vinolas A.', 'Sandgren T.', 'Moya C.', 'Huesler M.A.', 'Sela D.', 'Becker B.', 'Kuznetsov An.', 'El Aynaoui Y.', 'Smyczek T.', 'Musetti L.', 'Guccione C.', 'Marchenko I.', 'Zverev M.', 'Kopriva V.', 'Herbert P.H', 'Cressy M.', 'Rodionov J.', 'Dolgopolov O.', 'Norrie C.', 'Berrettini M.', 'Giron M.', 'Chela J.I.', 'Hanfmann Y.', 'Harrison R.', 'Gulbis E.', 'Olivo R.', 'Sousa J.', 'Mannarino A.', 'Matosevic M.', 'Laaksonen H.', 'Bedene A.', 'Andujar P.', 'Chardy J.', 'Sugita Y.', 'Kohlschreiber P.', 'Gojowczyk P.', 'Travaglia S.', 'Mathieu P.H.', '
# ...

# %% [markdown]
# - Obtén todos los jugadores que hayan ganado una final.

# %%
# Campeones

# Finalistas
# cantidad de partidos perdidos por jugador
champions = list()
for g in list_dic:
  if (g['Round'] == 'The Final'):
    champions.append(g['Winner'])

print (set(champions))
# Out:
# {'Jarry N.', 'Daniel T.', 'Troicki V.', 'Soderling R.', 'Cuevas P.', 'Medvedev D.', 'Humbert U.', 'Monaco J.', 'Garcia-Lopez G.', 'Seppi A.', 'Fognini F.', 'Djokovic N.', 'Nieminen J.', 'Zeballos H.', 'Auger-Aliassime F.', 'Cecchinato M.', 'Bellucci T.', 'Fucsovics M.', 'Paul T.', 'Dodig I.', 'Cerundolo J.M.', 'Ferrer D.', 'Tipsarevic J.', 'Tsonga J.W.', 'Llodra M.', 'Berdych T.', 'Londero J.I.', 'Carballes Baena R.', 'Rosol L.', 'Lopez F.', 'Petzschner P.', 'Paire B.', 'Murray A.', 'Johnson S.', 'Rublev A.', 'Karlovic I.', 'Berlocq C.', 'Davydenko N.', 'Del Potro J.M.', 'Mayer F.', 'Gonzalez F.', 'Schwartzman D.', 'Raonic M.', 'Querrey S.', 'Ginepri R.', 'Montanes A.', 'Sweeting R.', 'Kecmanovic M.', 'Sonego L.', 'Millman J.', 'Karatsev A.', 'Basic M.', 'Baghdatis M.', 'Federer R.', 'Dimitrov G.', 'Tursunov D.', 'Golubev A.', 'Shapovalov D.', 'Ruud C.', 'Kunitsyn I.', 'Bautista Agut R.', 'Anderson K.', 'Khachanov K.', 'Thiem D.', 'Almagro N.', 'Ramos-Vinolas A.', 'Sandgren T.', 'Sin
# ...

# %% [markdown]
# -

# %% [markdown]
# # Ordenamiento
# - Obtén los 20 jugadores con más partidos ganados y especifica cuántos partidos ganaron, si hay dos jugadores con la misma cantidad, ordénalos por orden alfabético de su nombre.

# %%
# top 10

# %% [markdown]
# - Obtén los 20 jugadores con más partidos perdidos y especifica cuántos partidos perdieron, si hay dos jugadores con la misma cantidad, ordénalos por total de partidos jugados.

# %%
# top 10
games_won

# %% [markdown]
# - Obtén una lista con los tipos de canchas que existen (pasto, arcilla, etc)

# %%
# Tipos de canchas

# %% [markdown]
# - Para cada tipo de cancha: Obtén una lista con los tres jugadores con más finales ganadas, y la cantidad de finales ganadas.
