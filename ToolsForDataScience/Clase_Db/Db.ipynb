# %%
import pandas as pd
from pandas import DataFrame
import numpy as np
from random import choices

ids = [234500, 240599, 213524]
comida = ["H","P","S","T"]

df1 = DataFrame ({"id1": choices(ids, k=7), "comida": choices(comida, k=7)})
df2 = DataFrame ({"id": ids + [234505, 223424],"status":["D", "ND", "ND", "ND", "D"]})

df1.iloc[0, 0] = "226404"
df1.index = df1["id1"]
df1.drop("id1", axis=1, inplace = True)

#df2.index = df2["id"]
#df2.drop("id", axis=1, inplace = True)

pd.merge(df1, df2, left_index = True, right_on = "id", how = "left")
#display(df1)
#display(df2)
#inner omite faltantes
#display(pd.merge(df1, df2, left_index = True, right_on = "id", how = "left"))
#display(pd.merge(df1, df2, left_index = True, right_on = "id", how = "right"))

df3 = DataFrame (df1.index)
df4 = DataFrame (comida)

pd.merge (df3, df4, how="cross")

df5 = DataFrame ({"id_restaurant":[100, 200, 300], "Nombre":["Cafe", "Umai Wok", "Nessu"]})
df6 = DataFrame ({"idr":[100, 200, 100, 300],"comida":["T", "S", "H", "P"]})
# Out:
# <ipython-input-54-34f06c546e20>:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '226404' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df1.iloc[0, 0] = "226404"

# %%
display (df2.where(df2["status"]=="D").merge(df1, left_on="id", right_index=True).merge(df6))
display (df2.where(df2["status"]=="D").merge(df1, left_on="id", right_index=True).merge(df6).merge(df5, left_on = "idr", right_on="id_restaurant"))
# Out:
#          id status comida  idr
# 0  234500.0      D      S  200
# 1  234500.0      D      H  100
#          id status comida  idr  id_restaurant    Nombre
# 0  234500.0      D      S  200            200  Umai Wok
# 1  234500.0      D      H  100            100      Cafe
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# <ipython-input-60-586bce13c9e4> in <cell line: 3>()
#       1 display (df2.where(df2["status"]=="D").merge(df1, left_on="id", right_index=True).merge(df6))
#       2 display (df2.where(df2["status"]=="D").merge(df1, left_on="id", right_index=True).merge(df6).merge(df5, left_on = "idr", right_on="id_restaurant"))
# ----> 3 display (df2.where(df2["status"]=="D").merge(df1, left_on="id", right_index=True).merge(df6).merge(df5))
#
# ...
