# %%
import pandas as pd
import numpy as np

data = pd.Series(np.random.randn(9), index= [["a", "a","a","b","b", "c", "c", "d", "d"], [1,2,3,1,2,3,1,2,3]])

# %%
data["a", 1]
# Out:
# 2.8136168987198675

# %%
data.unstack()
print (data.unstack())
data = data.unstack()
# Out:
#           1         2         3
# a  2.813617  0.835938 -0.342016
# b  0.342459  0.258138       NaN
# c -0.652853       NaN -0.746321
# d       NaN  0.296758 -0.982409

# %%
data.stack()
# Out:
# a  1    2.813617
#    2    0.835938
#    3   -0.342016
# b  1    0.342459
#    2    0.258138
# c  1   -0.652853
#    3   -0.746321
# d  2    0.296758
#    3   -0.982409
# dtype: float64

# %%
from pandas import DataFrame
df2 = DataFrame(np.arange(1,13).reshape(4,3), index = [["a", "a","b","b"], [1,2,1,2]], columns = [["Pera","Pera","Manzana"], ["Persa", "Asiatica", "Gala"]])

df2.index.names = ["Tamano", "Calidad"]
df2.columns.names = ["Fruta", "Variedad"]

# %%
df2.loc["a",1]["Pera"]
# Out:
# Variedad
# Persa       1
# Asiatica    2
# Name: (a, 1), dtype: int64

# %%
df2
# Out:
# Fruta           Pera          Manzana
# Variedad       Persa Asiatica    Gala
# Tamano Calidad
# a      1           1        2       3
#        2           4        5       6
# b      1           7        8       9
#        2          10       11      12

# %%
df2.unstack().unstack()
# Out:
# Fruta    Variedad  Calidad  Tamano
# Pera     Persa     1        a          1
#                             b          7
#                    2        a          4
#                             b         10
#          Asiatica  1        a          2
#                             b          8
#                    2        a          5
#                             b         11
# Manzana  Gala      1        a          3
#                             b          9
#                    2        a          6
#                             b         12
# dtype: int64

# %%
df2.swaplevel("Tamano", "Calidad")
df3 = df2.swaplevel("Tamano", "Calidad")
df3.sort_index()
# Out:
# Fruta           Pera          Manzana
# Variedad       Persa Asiatica    Gala
# Calidad Tamano
# 1       a          1        2       3
#         b          7        8       9
# 2       a          4        5       6
#         b         10       11      12

# %%
display(df2)
display(df2.T)

df2.T.groupby(level="Fruta").sum().sum(axis=1)
# Out:
# Fruta           Pera          Manzana
# Variedad       Persa Asiatica    Gala
# Tamano Calidad
# a      1           1        2       3
#        2           4        5       6
# b      1           7        8       9
#        2          10       11      12
# Tamano            a     b
# Calidad           1  2  1   2
# Fruta   Variedad
# Pera    Persa     1  4  7  10
#         Asiatica  2  5  8  11
# Manzana Gala      3  6  9  12
# Fruta
# Manzana    30
# Pera       48
# dtype: int64
