# %%
import matplotlib.pyplot as plt
import numpy    as np
from matplotlib import animation


fig = plt.figure(figsize = (5,3))

ax = fig.add_subplot()
ax.set_xlim(0, 2 * np.pi)
ax.set_ylim((-1.1, 1.1))
ax.grid(True)
ax.set_facecolor("xkcd:pistachio")

linea, = ax.plot([],[], lw=2)
n = 100

def init ():
    x = np.linspace (0, 2*np.pi, n)
    y = np.sin(x)
    linea.set_data(x, y)
    pass

f = 20

def animate(i):
    x = np.linspace (0, 2*np.pi, n)
    y = np.sin(x + 2 * np.pi * i / f)
    linea.set_data(x, y)
    return [linea]

# %%
from IPython.display import HTML

anim = animation.FuncAnimation(fig, animate, init_func = init, frames = f)
HTML (anim.to_jshtml())
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 4
#       1 from IPython.display import HTML
#       3 anim = animation.FuncAnimation(fig, animate, init_func = init, frames = f)
# ----> 4 HTML (anim.to_jshtml())
#
# File c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\animation.py:1353, in Animation.to_jshtml(self, fps, embed_frames, default_mode)
#    1349         path = Path(tmpdir, "temp.html")
#    1350         writer = HTMLWriter(fps=fps,
#    1351                             embed_frames=embed_frames,
#    1352                             default_mode=default_mode)
# -> 1353         self.save(str(path), writer=writer)
#    1354         self._html_representation = path.read_text()
#    1356 return self._html_representation
#
# File c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\animation.py:1105, in Animation.save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1102 for data in zip(*[a.new_saved_frame_seq() for a in all_anim]):
#    1103     for anim, d in zip(all_anim, data):
#    1104         # TODO: See if turning off blit is really necessary
# -> 1105         anim._draw_next_frame(d, blit=False)
#    1106         if progress_callback is not None:
#    1107             progress_callback(frame_number, total_frames)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\animation.py:1141, in Animation._draw_next_frame(self, framedata, blit)
#    1139 self._pre_draw(framedata, blit)
#    1140 self._draw_frame(framedata)
# -> 1141 self._post_draw(framedata, blit)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\animation.py:1166, in Animation._post_draw(self, framedata, blit)
#    1164     self._blit_draw(self._drawn_artists)
#    1165 else:
# -> 1166     self._fig.canvas.draw_idle()
#
# File c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\backend_bases.py:1893, in FigureCanvasBase.draw_idle(self, *args, **kwargs)
#    1891 if not self._is_idle_drawing:
#    1892     with self._idle_draw_cntx():
# -> 1893         self.draw(*args, **kwargs)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\backends\backend_agg.py:388, in FigureCanvasAgg.draw(self)
#     385 # Acquire a lock on the shared font cache.
#     386 with (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     387       else nullcontext()):
# --> 388     self.figure.draw(self.renderer)
#     389     # A GUI class may be need to update a window using this draw, so
#     390     # don't forget to call the superclass.
#     391     super().draw()
#
# File c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\artist.py:95, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      93 @wraps(draw)
#      94 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95     result = draw(artist, renderer, *args, **kwargs)
#      96     if renderer._rasterizing:
#      97         renderer.stop_rasterizing()
#
# File c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\figure.py:3154, in Figure.draw(self, renderer)
#    3151         # ValueError can occur when resizing a window.
#    3153 self.patch.draw(renderer)
# -> 3154 mimage._draw_list_compositing_images(
#    3155     renderer, self, artists, self.suppressComposite)
#    3157 for sfig in self.subfigs:
#    3158     sfig.draw(renderer)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\axes\_base.py:3070, in _AxesBase.draw(self, renderer)
#    3067 if artists_rasterized:
#    3068     _draw_rasterized(self.figure, artists_rasterized, renderer)
# -> 3070 mimage._draw_list_compositing_images(
#    3071     renderer, self, artists, self.figure.suppressComposite)
#    3073 renderer.close_group('axes')
#    3074 self.stale = False
#
# File c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\axis.py:1391, in Axis.draw(self, renderer, *args, **kwargs)
#    1388 tlb1, tlb2 = self._get_ticklabel_bboxes(ticks_to_draw, renderer)
#    1390 for tick in ticks_to_draw:
# -> 1391     tick.draw(renderer)
#    1393 # Shift label away from axes to avoid overlapping ticklabels.
#    1394 self._update_label_position(renderer)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\axis.py:295, in Tick.draw(self, renderer)
#     292 renderer.open_group(self.__name__, gid=self.get_gid())
#     293 for artist in [self.gridline, self.tick1line, self.tick2line,
#     294                self.label1, self.label2]:
# --> 295     artist.draw(renderer)
#     296 renderer.close_group(self.__name__)
#     297 self.stale = False
#
# File c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\lines.py:746, in Line2D.draw(self, renderer)
#     743     return
#     745 if self._invalidy or self._invalidx:
# --> 746     self.recache()
#     747 self.ind_offset = 0  # Needed for contains() method.
#     748 if self._subslice and self.axes:
#
# File c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\lines.py:678, in Line2D.recache(self, always)
#     675 else:
#     676     y = self._y
# --> 678 self._xy = np.column_stack(np.broadcast_arrays(x, y)).astype(float)
#     679 self._x, self._y = self._xy.T  # views
#     681 self._subslice = False
#
# File c:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\shape_base.py:652, in column_stack(tup)
#     650         arr = array(arr, copy=False, subok=True, ndmin=2).T
#     651     arrays.append(arr)
# --> 652 return _nx.concatenate(arrays, 1)
#
# KeyboardInterrupt:

# %%
import os
print(os.getcwd())
file = open ('animacion.html', 'w')
file.write (anim.to_jshtml())
file.close()
# Out:
# c:\Users\lanit\Especialidad\IA\ToolsForDataScience\MotionGraphics

# %%
#HTML(anim.to_html5_video())
from matplotlib import cm
cm.get_cmap("plasma")

import matplotlib
cmap = matplotlib.colormaps["plasma"]
display(cmap)
cmap(0)
colores = [cmap (x) for x in np.linspace(0, 1, 4)]
fig = plt.figure()
ax = fig.add_subplot()
f = 360
patches, labels = ax.pie([10, 20, 60 , 10], colors = colores)
# Out:
# C:\Users\lanit\AppData\Local\Temp\ipykernel_2524\3810771524.py:3: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cm.get_cmap("plasma")

# %%
#Animacion de un pay

fig = plt.figure()
ax = fig.add_subplot()
f = 360


height = [[1, 4, 1], [4, 2, 2], [2, 1,3]]
bins = [1, 2, 3]
#patches, labels = ax.hist([10, 10, 10, 80], colors = colores, explode = [0, 0, 0, 0])
ax.bar(bins,[1, 4, 1])

z = ax.bar(bins,[1, 4, 1])
def init():
    z = ax.bar(bins, height[0])
    return z

def animate (i):
    ax.clear()
     
    z = ax.bar(bins, (height[i % 3]).sort())
    return z

anim = animation.FuncAnimation(fig, animate, init_func = init, frames = 36, interval=300)
HTML (anim.to_jshtml())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 25
#      22     return z
#      24 anim = animation.FuncAnimation(fig, animate, init_func = init, frames = 36, interval=300)
# ---> 25 HTML (anim.to_jshtml())
#
# File c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\animation.py:1353, in Animation.to_jshtml(self, fps, embed_frames, default_mode)
#    1349         path = Path(tmpdir, "temp.html")
#    1350         writer = HTMLWriter(fps=fps,
#    1351                             embed_frames=embed_frames,
#    1352                             default_mode=default_mode)
# -> 1353         self.save(str(path), writer=writer)
#    1354         self._html_representation = path.read_text()
#    1356 return self._html_representation
#
# File c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\animation.py:1105, in Animation.save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1102 for data in zip(*[a.new_saved_frame_seq() for a in all_anim]):
#    1103     for anim, d in zip(all_anim, data):
#    1104         # TODO: See if turning off blit is really necessary
# -> 1105         anim._draw_next_frame(d, blit=False)
#    1106         if progress_callback is not None:
#    1107             progress_callback(frame_number, total_frames)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\animation.py:1140, in Animation._draw_next_frame(self, framedata, blit)
#    1136 def _draw_next_frame(self, framedata, blit):
#    1137     # Breaks down the drawing of the next frame into steps of pre- and
#    1138     # post- draw, as well as the drawing of the frame itself.
#    1139     self._pre_draw(framedata, blit)
# -> 1140     self._draw_frame(framedata)
#    1141     self._post_draw(framedata, blit)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\animation.py:1768, in FuncAnimation._draw_frame(self, framedata)
#    1764     self._save_seq = self._save_seq[-self._save_count:]
#    1766 # Call the func with framedata and args. If blitting is desired,
#    1767 # func needs to return a sequence of any artists that were modified.
# -> 1768 self._drawn_artists = self._func(framedata, *self._args)
#    1770 if self._blit:
#    1772     err = RuntimeError('The animation function must return a sequence '
#    1773                        'of Artist objects.')
#
# Cell In[5], line 21, in animate(i)
#      18 def animate (i):
#      19     ax.clear()
# ---> 21     z = ax.bar(bins, (height[i % 3]).sort())
#      22     return z
#
# File c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\__init__.py:1465, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1462 @functools.wraps(func)
#    1463 def inner(ax, *args, data=None, **kwargs):
#    1464     if data is None:
# -> 1465         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1467     bound = new_sig.bind(ax, *args, **kwargs)
#    1468     auto_label = (bound.arguments.get(label_namer)
#    1469                   or bound.kwargs.get(label_namer))
#
# File c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\axes\_axes.py:2524, in Axes.bar(self, x, height, width, bottom, align, **kwargs)
#    2521 args = zip(left, bottom, width, height, color, edgecolor, linewidth,
#    2522            hatch, patch_labels)
#    2523 for l, b, w, h, c, e, lw, htch, lbl in args:
# -> 2524     r = mpatches.Rectangle(
#    2525         xy=(l, b), width=w, height=h,
#    2526         facecolor=c,
#    2527         edgecolor=e,
#    2528         linewidth=lw,
#    2529         label=lbl,
#    2530         hatch=htch,
#    2531         )
#    2532     r._internal_update(kwargs)
#    2533     r.get_path()._interpolation_steps = 100
#
# File c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\patches.py:732, in Rectangle.__init__(self, xy, width, height, angle, rotation_point, **kwargs)
#     725 # Required for RectangleSelector with axes aspect ratio != 1
#     726 # The patch is defined in data coordinates and when changing the
#     727 # selector with square modifier and not in data coordinates, we need
#     728 # to correct for the aspect ratio difference between the data and
#     729 # display coordinate systems. Its value is typically provide by
#     730 # Axes._get_aspect_ratio()
#     731 self._aspect_ratio_correction = 1.0
# --> 732 self._convert_units()
#
# File c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\patches.py:743, in Rectangle._convert_units(self)
#     741 y0 = self.convert_yunits(self._y0)
#     742 x1 = self.convert_xunits(self._x0 + self._width)
# --> 743 y1 = self.convert_yunits(self._y0 + self._height)
#     744 return x0, y0, x1, y1
#
# TypeError: unsupported operand type(s) for +: 'int' and 'NoneType'
