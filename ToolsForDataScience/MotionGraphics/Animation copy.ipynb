# %%
import matplotlib.pyplot as plt
import numpy    as np
from matplotlib import animation


fig = plt.figure(figsize = (5,3))

ax = fig.add_subplot()
ax.set_xlim(0, 2 * np.pi)
ax.set_ylim((-1.1, 1.1))
ax.grid(True)
ax.set_facecolor("xkcd:pistachio")

linea, = ax.plot([],[], lw=2)
n = 100

def init ():
    x = np.linspace (0, 2*np.pi, n)
    y = np.sin(x)
    linea.set_data(x, y)
    pass

f = 20

def animate(i):
    x = np.linspace (0, 2*np.pi, n)
    y = np.sin(x + 2 * np.pi * i / f)
    linea.set_data(x, y)
    return [linea]

# %%
from IPython.display import HTML

anim = animation.FuncAnimation(fig, animate, init_func = init, frames = f)
HTML (anim.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
# ...

# %%
import os
print(os.getcwd())
file = open ('animacion.html', 'w')
file.write (anim.to_jshtml())
file.close()
# Out:
# c:\Users\lanit\Especialidad\IA\ToolsForDataScience\MotionGraphics

# %%
#HTML(anim.to_html5_video())
from matplotlib import cm
cm.get_cmap("plasma")

import matplotlib
cmap = matplotlib.colormaps["plasma"]
display(cmap)
cmap(0)
colores = [cmap (x) for x in np.linspace(0, 1, 4)]
fig = plt.figure()
ax = fig.add_subplot()
f = 360
patches, labels = ax.pie([10, 20, 60 , 10], colors = colores)
# Out:
# C:\Users\lanit\AppData\Local\Temp\ipykernel_11076\3810771524.py:3: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cm.get_cmap("plasma")

# %%
#Animacion de un pay

fig = plt.figure()
ax = fig.add_subplot()
f = 360


height = [[1, 4, 1], [4, 2, 2], [2, 1,3]]
bins = [1, 2, 3]
#patches, labels = ax.hist([10, 10, 10, 80], colors = colores, explode = [0, 0, 0, 0])
ax.bar(bins,[1, 4, 1])

z = ax.bar(bins,[1, 4, 1])
def init():
    z = ax.bar(bins, height[0])
    return z

def animate (i):
    ax.clear()
     
    z = ax.bar(bins, (height[i % 3]))
    return z

anim = animation.FuncAnimation(fig, animate, init_func = init, frames = 36, interval=300)
HTML (anim.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
# ...

# %%
import matplotlib.pyplot as plt
from matplotlib import animation

fig = plt.figure (figsize = (8, 3))
ax = fig.add_subplot ()

ax.set_xlim (0, 5.5)
ax.set_ylim (.5, 3.5)
ax.set_yticks ([1, 2, 3])

v1 = [1, 3, 5]
abars = ax.barh ([1, 2,3], v1)
n_frames = 30
def animate (i):
    ax.clear()
    
    ax.set_xlim (0, 5.5)
    ax.set_ylim (.5, 3.5)
    ax.set_yticks ([1, 2, 3])

    z = ax.barh([1,2,3], (v1[n_frames % 3], 0, 0))
    return z

anim = animation.FuncAnimation(fig, animate, frames = 3, interval=100)
HTML (anim.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
# ...

# %%
# Out:
#     val1  pos1
# 0      1     1
# 10     3     2
# 20     5     3

# %%
import pandas as pd
from matplotlib import colormaps
print (list(colormaps))
#cmap = colarmaps ["Spectral"]

#colores = [cmap(i), for i in np.linespace (0, 1, 3)]

p1 = [1,2,3]
v2 = [5, 1, 5]
p_2 = [3, 1, 2]
df = pd.DataFrame({"val1": v1, "pos1":p1,"val2": v2, "pos2":p_2})

                  
n_inter = 10

df.index = df.index * n_inter
df
df.reindex (range (0, df.index[-1]+1))

df = df.reindex (range (0, df.index[-1]+1))
df = df.interpolate()

fig = plt.figure (figsize = (8, 3))
ax = fig.add_subplot ()

ax.set_xlim (0, 5.5)
ax.set_ylim (.5, 3.5)
ax.set_yticks ([1, 2, 3])

v1 = [1, 3, 5]

abars = ax.barh ([1, 2,3], df["val1"][0])
n_frames = len (df)

def animate (i):
    ax.clear()
    
    ax.set_xlim (0, 5.5)
    ax.set_ylim (.5, 3.5)
    ax.set_yticks ([1, 2, 3])

    z = ax.barh( [df["pos1"][i % n_frames], df["pos2"][i % n_frames], 3], [df["val1"][i  % n_frames], df["val2"][i  % n_frames], 0])
                #colors = colores)
    return z
anim = animation.FuncAnimation(fig, animate, frames = n_frames, interval=100)
js = anim.to_jshtml()
HTML(js)
# Out:
# ['magma', 'inferno', 'plasma', 'viridis', 'cividis', 'twilight', 'twilight_shifted', 'turbo', 'Blues', 'BrBG', 'BuGn', 'BuPu', 'CMRmap', 'GnBu', 'Greens', 'Greys', 'OrRd', 'Oranges', 'PRGn', 'PiYG', 'PuBu', 'PuBuGn', 'PuOr', 'PuRd', 'Purples', 'RdBu', 'RdGy', 'RdPu', 'RdYlBu', 'RdYlGn', 'Reds', 'Spectral', 'Wistia', 'YlGn', 'YlGnBu', 'YlOrBr', 'YlOrRd', 'afmhot', 'autumn', 'binary', 'bone', 'brg', 'bwr', 'cool', 'coolwarm', 'copper', 'cubehelix', 'flag', 'gist_earth', 'gist_gray', 'gist_heat', 'gist_ncar', 'gist_rainbow', 'gist_stern', 'gist_yarg', 'gnuplot', 'gnuplot2', 'gray', 'hot', 'hsv', 'jet', 'nipy_spectral', 'ocean', 'pink', 'prism', 'rainbow', 'seismic', 'spring', 'summer', 'terrain', 'winter', 'Accent', 'Dark2', 'Paired', 'Pastel1', 'Pastel2', 'Set1', 'Set2', 'Set3', 'tab10', 'tab20', 'tab20b', 'tab20c', 'grey', 'gist_grey', 'gist_yerg', 'Grays', 'magma_r', 'inferno_r', 'plasma_r', 'viridis_r', 'cividis_r', 'twilight_r', 'twilight_shifted_r', 'turbo_r', 'Blues_r', 'BrBG_r',
# ...

# %%
v1 = [1, 2, 6]
v2 = [5, 1, 5]
v3 = [3, 5, 2]

df2 = pd.DataFrame ({"val1":v1, "val2":v2, "val3":v3})
display (df2)
df2.rank()
df2.rank (axis = 1, ascending = False)
# Out:
#    val1  val2  val3
# 0     1     5     3
# 1     2     1     5
# 2     6     5     2
#    val1  val2  val3
# 0   3.0   1.0   2.0
# 1   2.0   3.0   1.0
# 2   1.0   2.0   3.0

# %%
ham = [90, 90, 82, 82, 82]
per = [85, 82, 81, 86, 81]
ver = [71, 71, 87, 87, 81]

df3 = pd.DataFrame({"ham":ham, "per":per, "ver":ver})
n_inter = 10
df3.index = df3.index * n_inter
df3
df3 = df3.reindex (range (0, df3.index[-1]+1))
df3 = df3.interpolate()

df3p = df3.rank (axis = 1)

n_frames = len (df3)

df3p.head(20)

#df3.head(20)


z = ax.barh([df3p["ham"][0 % n_frames], df3p["per"][0 % n_frames],df3p["ver"][0 % n_frames], 3],
    [df3["ham"][0  % n_frames], df3["per"][0  % n_frames], 0, df3["ver"][0  % n_frames]])

# %%
def animate (i):
    ax.clear()
    
    ax.set_xlim (0, 100)
    ax.set_ylim (0, 4)
    ax.set_yticks ([1, 2, 3])

    z = ax.barh([df3p["ham"][i % n_frames], df3p["per"][i % n_frames],df3p["ver"][i % n_frames], 3],
        [df3["ham"][i  % n_frames], df3["per"][i  % n_frames], 0, df3["ver"][i  % n_frames]])
                #colors = colores)
    return z

anim = animation.FuncAnimation(fig, animate, frames = n_frames, interval=100)
js = anim.to_jshtml()
HTML(js)
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
# ...
