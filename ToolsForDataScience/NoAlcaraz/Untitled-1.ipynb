# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

import seaborn as sns
import warnings

warnings.filterwarnings('ignore')

data = sns.load_dataset('tips')
sns.catplot(x = 'day', y='total_bill', data=data)
plt.title("Total per day")
# Out:
# Text(0.5, 1.0, 'Total per day')

# %%
accident = pd.read_csv('ACCIDENTES DE TRANSITO GEORREFERENCIADOS 2022.csv', encoding = 'latin-1')
pd.to_datetime(accident[['ANIO', 'MES', 'DIA']].rename()
